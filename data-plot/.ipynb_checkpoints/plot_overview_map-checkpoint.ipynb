# %%
# Create a figure
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import cmocean.cm as cmo
import matplotlib.pyplot as plt
import xarray as xr
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/n5/s6yw8y811f7bqlr9nb7w5rsr0000gn/T/ipykernel_65326/826947002.py in <module>
#       1 # Create a figure
# ----> 2 import cartopy.crs as ccrs
#       3 import cartopy.feature as cfeature
#       4 import cmocean.cm as cmo
#       5 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'cartopy'

# %%
seaice = xr.open_mfdataset('../data-load/asi*.hdf', engine='netcdf4')
# Out:
# /Users/marcel/opt/anaconda3/envs/duplessis2021_JGR/lib/python3.9/site-packages/xarray/backends/plugins.py:61: RuntimeWarning: Engine 'cfgrib' loading failed:
# Cannot find the ecCodes library
#   warnings.warn(f"Engine {name!r} loading failed:\n{ex}", RuntimeWarning)

# %%
sst   = xr.open_dataset('../../data/sst_latest.nc')
wind  = xr.open_dataset('../../data/wind_gfs_latest.nc')

seaice_ll = xr.open_dataset('../../data/LongitudeLatitudeGrid-s6250-Antarctic.hdf', engine='netcdf4')
seaice    = xr.open_dataset('../../data/seaice_latest.hdf', engine='netcdf4')

# %%
sst
# Out:
# <xarray.Dataset>
# Dimensions:       (lat: 5001, lon: 5001, time: 1)
# Coordinates:
#   * lat           (lat) float32 -80.0 -79.99 -79.98 ... -30.02 -30.01 -30.0
#   * lon           (lon) float32 0.0 0.01 0.02 0.03 ... 49.97 49.98 49.99 50.0
#   * time          (time) datetime64[ns] 2021-12-14T09:00:00
# Data variables:
#     analysed_sst  (time, lat, lon) float32 ...
#     masked_sst    (time, lat, lon) float32 ...
# Attributes: (12/52)
#     Conventions:                CF-1.7
#     title:                      Daily MUR SST, Final product
#     summary:                    A merged, multi-sensor L4 Foundation SST anal...
#     references:                 http://podaac.jpl.nasa.gov/Multi-scale_Ultra-...
#     institution:                Jet Propulsion Laboratory
#     history:                    created at nominal 4-day latency; replaced nr...
#     ...                         ...
#     cdm_data_type:              grid
# ...

# %%
wind
# Out:
# <xarray.Dataset>
# Dimensions:                                  (time: 24, lat: 201, lon: 201)
# Coordinates:
#   * time                                     (time) datetime64[ns] 2021-12-15...
#     height_above_ground4                     float32 ...
#   * lat                                      (lat) float32 -30.0 ... -80.0
#   * lon                                      (lon) float32 0.0 0.25 ... 50.0
# Data variables:
#     v-component_of_wind_height_above_ground  (time, lat, lon) float32 ...
#     LatLon_Projection                        int32 ...
#     u-component_of_wind_height_above_ground  (time, lat, lon) float32 ...
#     wind_magnitude                           (time, lat, lon) float32 ...
# Attributes: (12/13)
#     Originating_or_generating_Center:                                        ...
#     Originating_or_generating_Subcenter:                                     ...
#     GRIB_table_version:                                                      ...
# ...

# %%
fig = plt.figure(figsize=[14,8])
ax = plt.axes(projection=ccrs.Mercator())
cs=wind.wind_magnitude.plot(transform=ccrs.PlateCarree(),
                              cmap=cmo.thermal,add_colorbar=False)

### this fills out white space 
ax.set_title('')
# plt.gca().outline_patch.set_visible(False)
ax.spines['geo'].set_visible(False)
# extent = ax.get_window_extent().transformed(fig.dpi_scale_trans.inverted())  
plt.gca().xaxis.set_major_locator(plt.NullLocator())
plt.gca().yaxis.set_major_locator(plt.NullLocator())
plt.margins(0,0)

# plt.savefig('sst_{}.png'.format((sst.time.dt.strftime("%Y%m%d")).values.tolist()[0]),transparent=True,dpi=150,bbox_inches='tight', pad_inches=0)
# plt.savefig('latest.png'.format((sst.time.dt.strftime("%Y%m%d")).values.tolist()[0]),transparent=True,dpi=150,bbox_inches='tight', pad_inches=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/n5/s6yw8y811f7bqlr9nb7w5rsr0000gn/T/ipykernel_65326/2643676237.py in <module>
#       1 fig = plt.figure(figsize=[14,8])
# ----> 2 ax = plt.axes(projection=ccrs.Mercator())
#       3 cs=wind.wind_magnitude.plot(transform=ccrs.PlateCarree(),
#       4                               cmap=cmo.thermal,add_colorbar=False)
#       5
#
# NameError: name 'ccrs' is not defined
